# %% [markdown]
# PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS\
# PROFESSOR: LEANDRO FIGUEIRA LESSA\
# INTEGRANTES DO GRUPO:
# &nbsp;&nbsp;&nbsp;&nbsp;Charlene Aparecida Salustiano de Jesus
# &nbsp;&nbsp;&nbsp;&nbsp;Edimilson Estevam da Cruz
# &nbsp;&nbsp;&nbsp;&nbsp;Lucas Cinquenti Moreira
# &nbsp;&nbsp;&nbsp;&nbsp;Michele Mayumi Miyazaki
# DISCIPLINA: PYTHON PARA CIÊNCIA DE DADOS\
# ATIVIDADE: ANÁLISE DO DESENVOLVIMENTO HUMANO E ECONÔMICO GLOBAL
# ______________________________________________________________________________

# %% [markdown]
# ### Análise do Desenvolvimento Humano e Econômico Global com Base no Dataset Gapminder: uma perspectiva sobre as desigualdades
# ______________________________________________________________________________

# %% [markdown]
# ### 1. Introdução
#
# Com base no Dataset Gpminder realizamos uma análise descritiva e exploratória sobre os dados relacionados à população, expectativa de vida e renda per capita dos países que compõem o globo terrestre. Estes dados estão divididos entre os anos de 1952 e 2007, sendo agrupados a cada 5 anos.
#
# A análise nos permitirá visualizar as desigualdades sociais e econômicas, dificuldades no desenvolvimento humano, o crescimento econômico de alguns países, as discrepâncias entre os continentes, além de como o aspecto populacional pode ou não influenciar no progresso de uma nação.
#
# Assim que começamos as análises exploratória encontramos uma disparidade com relação ao PIB do Kwait, que apresentou números muito altos destoando dos demais países. Pesquisamos então a fonte de dados Gapminder ('https://www.gapminder.org/data/') e encontramos dados diferentes da base que foi disposta para a execução deste trabalho. Então, apresentaremos um comparativo entre as bases de dados, e o grupo decidiu retirar este país das análises seguintes para não interferir nos valores médios buscados.
#
# A análise começará mostrando o crescimento populacional por Continente de 1953 a 2007. Em seguida, visualizaremos o crescimento da Longevidade por Continente, no mesmo período. Observou-se então, que o continente asiático é o mais populoso, e então fizemos uma análise dos países mais populosos deste continente, e depois a mesma análise foi aplicada aos países oceânicos e europeu.
#
# Com isso, serão apresentados as análises e gráficos de 10 países com maior destaque no PIB nos diferentes anos consultados, bem como suas evoluções.
#
# Na sequência exploramos os dados relacionados à expectativa de vida, e foram observadas relações diretas com o PIB. Quanto maior a renda per capita de um país, maior é a expectativa de vida.

# %% [markdown]
# ### 2.  Coleta, Limpeza e Análise Exploratória (AED)

# %% [markdown]
# ### 2.1 Configurando Ambiente

# %%
# PARA A INSTALAÇÃO DOS REQUISITOS, BIBLIOTECAS E PACOTES EXTERNOS PARA O PROJETO SER EXECUTADO
# %pip install -r ../requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2.1.1 Bibliotecas

# %%
#PARA IMPORTAR AS BIBLIOTECAS PYTHON USADAS NO PROJETO
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2.2 Coleta dos Dados

# %% [markdown]
# ### 2.2.1 Leitura da base de dados

# %%
#PARA DEFINIÇÃO DA VARIÁVEL DE LEITURA DO ARQUIVO
arquivo = 'gapminder_full.csv'

# %%
#PARA LEITURA DO ARQUIVO E INDICAÇÃO DO SEPARADOR DAS COLUNAS
df = pd.read_csv(arquivo, sep=',')

# %% [markdown]
# ### 2.2.1 Visualização dos Dados

# %%
#PARA A INSPEÇÃO DA ESTRUTURA DOS DADOS
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
#PARA VISUALIZAR O RESUMO DA ESTRUTURA DE DADOS
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1736 non-null   object
#  1   year       1736 non-null   int64
#  2   pop        1736 non-null   float64
#  3   continent  1736 non-null   object
#  4   lifeExp    1736 non-null   float64
#  5   gdpPercap  1736 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 81.5+ KB

# %% [markdown]
# ### 2.2.2 Descrição dos dados

# %%
#PARA CONHECER AS COLUNAS
dataset.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='str')

# %% [markdown]
# ##### 2.2.2.1 Colunas com valores numéricos:

# %%
#PARA COLUNAS COM VALORES NUMÉRICOS
numeric_cols = dataset.select_dtypes(include=["number"]).columns
print(numeric_cols)
# Out:
# Index(['year', 'pop', 'lifeExp', 'gdpPercap'], dtype='str')

# %% [markdown]
# ##### 2.2.2.2 Colunas com valores categóricos:

# %%
#PARA COLUNAS COM VALORES CATEGORICOS
cat_cols = dataset.select_dtypes(include=["object"]).columns
print(cat_cols)
# Out:
# Index(['country', 'continent'], dtype='str')
# /tmp/ipykernel_222498/3641821407.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = dataset.select_dtypes(include=["object"]).columns

# %% [markdown]
# ### 2.3 Limpeza e tratamento dos dados

# %% [markdown]
# ### 2.3.1 - Tipos de dados
# Identificamos a necessidade de ajustar os tipos de dados de algumas colunas, então alteramos as colunas: 'country' e 'continent' de 'objeto' para 'string' e a coluna 'pop' de 'float64' para  'int', este último foi alterado para facilitar nos cálculos de média, uma vez que as pessoas são contadas como inteiras.

# %%
df["country"]=df["country"].astype("string")
df["continent"]=df["continent"].astype("string")
df["pop"]=df["pop"].astype("int")

# %%
#PARA EXIBIR OS TIPOS DE DADOS TRATADOS
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1736 non-null   string
#  1   year       1736 non-null   int64
#  2   pop        1736 non-null   int64
#  3   continent  1736 non-null   string
#  4   lifeExp    1736 non-null   float64
#  5   gdpPercap  1736 non-null   float64
# dtypes: float64(2), int64(2), string(2)
# memory usage: 81.5 KB

# %%
#PARA EXIBIR OS DADOS APÓS O TRATAMENTO
df.describe()
# Out:
#               year           pop      lifeExp      gdpPercap
# count  1736.000000  1.736000e+03  1736.000000    1736.000000
# mean   1979.669931  3.156800e+07    59.511979    7240.155986
# std      17.296364  1.172888e+08    12.956028    9839.873695
# min    1952.000000  6.001100e+04    23.599000     241.165876
# 25%    1967.000000  2.818694e+06    48.245000    1202.060309
# 50%    1982.000000  7.150606e+06    60.808000    3534.772106
# 75%    1997.000000  1.977102e+07    70.945000    9380.254270
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# ### 2.3.2 Dados duplicados
# Seguindo com o tratamento dos dados, buscamos identificar se haviam dados duplicados. E na análise encontramos 32 linhas duplicadas.

# %%
#PARA A CONTAGEM DOS DADOS DUPLICADOS
df.duplicated().sum()
# Out:
# np.int64(32)

# %% [markdown]
# Após a identificação utilizamos a função drop_duplicates() para eliminar os dados duplicados

# %%
#PARA APAGAR AS LINHAS DUPLICADAS
df = df.drop_duplicates()

# %%
#PARA CONFERIR SE AS LINHAS DUPLICADAS FORAM APAGADAS CORRETAMENTE
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 2.3.3 Dados ausentes
# Outro ponto importante para o tratamento dos dados é indicar se há dados ausentes. Então, aplicamos a função python .isna() em conjunto com a função .sum() para contabilizar as ausências. Porém, não as encontramos, então não houve a necessidade de tratamento.

# %%
df.isna().sum()
# Out:
# country      0
# year         0
# pop          0
# continent    0
# lifeExp      0
# gdpPercap    0
# dtype: int64

# %% [markdown]
# ### 2.4 Análise Exploratória dos Dados

# %% [markdown]
# #### 2.4.1 Identificação e Ajuste de Outliers

# %% [markdown]
# Realizamos as análises da base de dados, e encontrados dados discrepantes com relação ao PIB do Kwait.
#
# Os valores estão muito altos, conforme GRÁFICO 1.

# %%
#PARA APRESENTAÇÃO DO PIB NO GRÁFICO
pib_country = (
    dataset.groupby(["country", "continent"])["gdpPercap"]
    .mean()
    .reset_index()
)

top_pib = pib_country.sort_values(
    by="gdpPercap",
    ascending=False
).head(20)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_pib,
    x="gdpPercap",
    y="country",
    hue="continent"
)

plt.title("Top 20 países por GDP médio")
plt.xlabel("GDP médio")
plt.ylabel("País")

plt.show()

# %% [markdown]
# <center><span style="font-size: 0.7em;">GRAFICO 1</span></center>

# %% [markdown]
# Filtramos o país Kuwait e utilizando a função python .head() é possível observar que o PIB está muito alto especialmente nos anos de 1952, 1957 e 1972 que ultrapassam os 6 dígitos.

# %%
#PARA O FILTRO DO PAÍS KUWAIT
filtro = df["country"] == "Kuwait"
df[filtro]

df[filtro].head(20)
# Out:
#     country  year        pop continent  lifeExp     gdpPercap
# 884  Kuwait  1952   160000.0      Asia   55.565  108382.35290
# 885  Kuwait  1957   212846.0      Asia   58.033  113523.13290
# 886  Kuwait  1962   358266.0      Asia   60.470   95458.11176
# 887  Kuwait  1967   575003.0      Asia   64.624   80894.88326
# 888  Kuwait  1972   841934.0      Asia   67.712  109347.86700
# 889  Kuwait  1977  1140357.0      Asia   69.343   59265.47714
# 890  Kuwait  1982  1497494.0      Asia   71.309   31354.03573
# 891  Kuwait  1987  1891487.0      Asia   74.174   28118.42998
# 892  Kuwait  1992  1418095.0      Asia   75.190   34932.91959
# 893  Kuwait  1997  1765345.0      Asia   76.156   40300.61996
# 894  Kuwait  2002  2111561.0      Asia   76.904   35110.10566
# 895  Kuwait  2007  2505559.0      Asia   77.588   47306.98978

# %% [markdown]
# Buscamos na base de dados do 'https://www.gapminder.org/data/' no menu de 'GPD per capita, PPP (constant 2021 internacional $)' comprovamos valores distintos.

# %%
#PARA A LEITURA DA NOVA BASE COM OS DADOS CORRETOS

# %%
#PARA A APRESENTAÇÃO GRÁFICA DOS DADOS CORRETOS COMPARADOS COM OS INCORRETOS, CONFORME GRÁFICO 2
# (AQUI VAI O GRÁFICO DO LUCAS)

# %% [markdown]
# <center><span style="font-size: 0.7em;">GRAFICO 2</span></center>

# %% [markdown]
# Diante destas informações, o grupo tomou a decisão de retirar o país Kwait das análises seguintes, a fim de não interferir nos resultados dos cálculos de PIB.
# Para os cálculos relacionados à população e à expectativa de vida, o país será mantido, pois não houve observação de dados incorretos nestes quesitos.

# %% [markdown]
# ### 3.  Funções de Visualização e Análise Gráfica

# %% [markdown]
# ### 3.1 Criação das Funções

# %%
#INCLUSÃO DAS FUNÇÕES

# %% [markdown]
# ### 3.2 População - Visualização e Análise Gráfica
# Iniciaremos as análises pela população. Com o objetivo de reconhecer os padrões regionais e históricos dos países e continentes, bem como a evolução dessas métricas ao longo de cinco décadas.

# %% [markdown]
# #### 3.2.1 População na Ásia

# %%
#PARA O FILTRO DO CONTINENTE
dados = df[
    (df['continent'] == 'Asia') &
    (df['year'].between(1953, 2007))
]

#PARA A CONFIGURAÇÃO DO GRÁFICO
plt.figure(figsize=(20,6))

sns.barplot(
    data=dados,
    x='country',
    y='pop',
    order=dados.sort_values('pop', ascending=False)['country']
)

plt.xticks(rotation=90)

plt.title('Países Asiáticos Mais Populosos (1953-2007)')
plt.xlabel('Países')
plt.ylabel('População')
plt.show()

# %% [markdown]
# ### 3.3 PIB - Visualização e Análise Gráfica

# %% [markdown]
# ### 3.4 Expectativa de Vida - Visualização e Análise Gráfica

# %% [markdown]
# #### PIB por ano e por País

# %% [markdown]
# #### PIB por continente

# %% [markdown]
# #### Análise Populacional para o PIB

# %% [markdown]
# #### Influência da Expectativa de Vida no PIB

# %% [markdown]
# #### Análise de Correlação
